# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
s='Hello World'

s[2]
# Out:
# 'l'

# %%
s='Hello World'

s[3:7]
# Out:
# 'lo W'

# %%
var=(2, 6, 8, "Apple", "Mango", 94)

# %%
var
# Out:
# (2, 6, 8, 'Apple', 'Mango', 94)

# %%
list1 = [2, 6, 8, "Apple", "Mango", 94, "Dhaka", "Hriddho", 7, 3]

list1.index("Mango")
# Out:
# 4

# %%
s = "Hello World"

s.index("H")
# Out:
# 0

# %%
s = "Hello World"

s.index("r")
# Out:
# 8

# %%
s = "Hello World"

s.split()
# Out:
# ['Hello', 'World']

# %%
s = "Hello World"

s.split("W")
# Out:
# ['Hello ', 'orld']

# %%
s = "Hello World"

s.split("o")
# Out:
# ['Hell', ' W', 'rld']

# %%
list2 = [2, 6, 8, "Apple", "Mango", 94, "Dhaka", "Hriddho", 7, 3]

list2.index("Hriddho")
# Out:
# 7

# %%
s = "Hello World"

s.split("l")
# Out:
# ['He', '', 'o Wor', 'd']

# %%
list_s = s.split("o")

list_s
# Out:
# ['Hell', ' W', 'rld']

# %%
"".join(list_s)
# Out:
# 'Hell Wrld'

# %%
"o".join(list_s)
# Out:
# 'Hello World'

# %%
s = s.replace("o", "O")

# %%
s
# Out:
# 'HellO WOrld'

# %%
s = s.replace("O", "OO")

# %%
s
# Out:
# 'HellOO WOOrld'

# %%
s = s.replace("O", "PA")

# %%
s
# Out:
# 'HellPAPA WPAPArld'

# %%
s.title()
# Out:
# 'Hellpapa Wpaparld'

# %%
s = "my name is hriddho"

s.title()
# Out:
# 'My Name Is Hriddho'

# %%
s.capitalize()
# Out:
# 'My name is hriddho'

# %%
s.upper()
# Out:
# 'MY NAME IS HRIDDHO'

# %%
s.lower()
# Out:
# 'my name is hriddho'

# %%
s.count("d")
# Out:
# 2

# %%
s.count("Z")
# Out:
# 0

# %%
len(s)
# Out:
# 18

# %%
A = "Hello"

A + " World"
# Out:
# 'Hello World'

# %%
A.replace("H", " ")
# Out:
# ' ello'

# %%
A.replace("H", "Z")
# Out:
# 'Zello'

# %%
A.replace("o", "68")
# Out:
# 'Hell68'

# %%
tuple1 = (1, "HJ", "Add", 74, "iphone", 7, 2, 4, 342, "Tim", 6, 23, 432, "Raiyan", "Features", 7, 0, 3)

tuple1[0]
# Out:
# 1

# %%
tuple1[7]
# Out:
# 4

# %%
type(tuple1)
# Out:
# tuple

# %%
tuple1 = (1, [4,5,6], "one")

tuple1[1][1]=50

# %%
tuple1
# Out:
# (1, [4, 50, 6], 'one')

# %%
t = (1,2,3)

l = list(t)

l[1] = 20

l
# Out:
# [1, 20, 3]

# %%
t = (1, 2, 3)

l = list(t)

l[1]=20

t1 = tuple(l)

t1
# Out:
# (1, 20, 3)

# %%
type(t1)

tuple
# Out:
# tuple

# %%
s='12 35'

s.rstrip()
# Out:
# '12 35'

# %%
s='12 35'

''.join(s.split())
# Out:
# '1235'

# %%
my_list = [1, 2, 3, 4, 5]

print(my_list[:])
# Out:
# [1, 2, 3, 4, 5]

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = " Hello, World! "
print(a.strip())
# Out:
# Hello, World!

# %%
list1={1}

# %%
type(list1)
# Out:
# set

# %%
list1 = [1,1,1,3,4,5]

set1={1,1,1,3,4,5}

list1,set1
# Out:
# ([1, 1, 1, 3, 4, 5], {1, 3, 4, 5})

# %%
set1 = {1,2,3,4}

set2 = {7,8,9}

set1.add(100)

set1
# Out:
# {1, 2, 3, 4, 100}

# %%
set1.remove(4)

# %%
set1
# Out:
# {1, 2, 3, 100}

# %%
set1 = {1,2,3,4,5,6}

set2 = {7,8,9,1,2,3}

set1.intersection(set2)
# Out:
# {1, 2, 3}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
set1.difference(set2)
# Out:
# {4, 5, 6}

# %%
set2.difference(set1)
# Out:
# {7, 8, 9}

# %%
set2.intersection(set1)
# Out:
# {1, 2, 3}

# %%
set3 = set1.difference(set2)

set3
# Out:
# {4, 5, 6}

# %%
set1.update(set2)

set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}

set2 = {1, 5, 7, 9, 3}

set3 = {True, False, False}

print(set1)

print(set2)

print(set3)
# Out:
# {'apple', 'cherry', 'banana'}
# {1, 3, 5, 7, 9}
# {False, True}

# %%
Dict = {1: 'Lets', 2: 'Fun', 3: 'Today'}
print(Dict)
# Out:
# {1: 'Lets', 2: 'Fun', 3: 'Today'}

# %%
Dict = {1: 'Creative', 2: 'For',
        3: {'A': 'IT', 'B': 'To', 'C': 'Institute'}}
  
print(Dict)
# Out:
# {1: 'Creative', 2: 'For', 3: {'A': 'IT', 'B': 'To', 'C': 'Institute'}}

# %%
Dict = {'Dict1': {1: 'Python'},
        'Dict2': {'Machine': 'Learning'}}
  
# Accessing element using key
print(Dict['Dict1'])
print(Dict['Dict1'][1])
print(Dict['Dict2']['Machine'])
# Out:
# {1: 'Python'}
# Python
# Learning

# %%
age = 23
txt = "My name is Hriddho, and I am {}"
print(txt.format(age))
# Out:
# My name is Hriddho, and I am 23

# %%
quantity = 3
itemno = 567
price = 49.95
myorder = "I want to pay {2} dollars for {0} pieces of item {1}."
print(myorder.format(quantity, itemno, price))
# Out:
# I want to pay 49.95 dollars for 3 pieces of item 567.

# %%
capital_city = {"Japan": "Tokyo", "Bangladesh": "Dhaka", "India": "New Delhi"}
print(capital_city)
# Out:
# {'Japan': 'Tokyo', 'Bangladesh': 'Dhaka', 'India': 'New Delhi'}

# %%
numbers = {1: "One", 2: "Two", 3: "Three"}
print(numbers)
# Out:
# {1: 'One', 2: 'Two', 3: 'Three'}
